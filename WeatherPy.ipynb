# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There does not seem to be a very strong correlation between latitude and humidity but there does seem to be slightly more cities to the North with lower humidity compared to South of the equator.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0 and 78% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Base URL
url = 'http://api.openweathermap.org/data/2.5/weather?q='

#make empty lists to fill with the data from the API website
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []
city_list = []
counter = 1
        
# Get weather data
for city in cities: 
    try:
        print(f'Processing City # {counter} of 602 | {city}')
        query = requests.get(url + city + '&units=imperial' +'&APPID='+ api_key).json()
        cloudiness.append(query['clouds']['all'])
        city_list.append(city)
        country.append(query['sys']['country'])
        date.append(query['dt'])
        humidity.append(query['main']['humidity'])
        lat.append(query['coord']['lat'])
        lng.append(query['coord']['lon'])
        maxtemp.append(query['main']['temp_max'])
        windspeed.append(query['wind']['speed'])
        
    except KeyError:
        print('city not found. skipping....') 
        pass
    
    counter += 1
# Out:
# Processing City # 1 of 602 | hambantota
# Processing City # 2 of 602 | olinda
# Processing City # 3 of 602 | port alfred
# Processing City # 4 of 602 | matagami
# Processing City # 5 of 602 | hermanus
# Processing City # 6 of 602 | butaritari
# Processing City # 7 of 602 | georgetown
# Processing City # 8 of 602 | goderich
# Processing City # 9 of 602 | upernavik
# Processing City # 10 of 602 | guerande
# Processing City # 11 of 602 | ushuaia
# Processing City # 12 of 602 | port elizabeth
# Processing City # 13 of 602 | inuvik
# Processing City # 14 of 602 | san patricio
# Processing City # 15 of 602 | vaitupu
# city not found. skipping....
# Processing City # 16 of 602 | cidreira
# Processing City # 17 of 602 | jamestown
# Processing City # 18 of 602 | barrow
# Processing City # 19 of 602 | rikitea
# Processing City # 20 of 602 | sekoma
# Processing City # 21 of 602 | centerville
# Processing City # 22 of 602 | taolanaro
# city not found. skipping....
# Processing City # 23 of 602 | albany
# Processing City # 24 of 602 | punta arenas
# Processing City # 25 of 602 | new norfolk
# Processing City # 26 of 602 | mount isa
# Processing City # 27 of 602 | chokurdakh
# Processing City # 28 of 602 | bambous virieux
# Processing City # 29 of 602 | gorkovskoye
# city not found. skipping....
# Processing City # 30 of 602 | east london
# Processing City # 31 of 602 | constitucion
# Processing City # 32 of 602 | kimi
# city not found. skipping....
# Processing City # 33 of 602 | umzimvubu
# city not found. skipping....
# Processing City # 34 of 602 | yellowknife
# Processing City # 35 of 602 | atuona
# Processing City # 36 of 602 | hobyo
# Processing City # 37 of 602 | englewood
# Processing City # 38 of 602 | vanimo
# Processing City # 39 of 602 | goure
# Processing City # 40 of 602 | kavieng
# Processing City # 41 of 602 | bethel
# Processing City # 42 of 602 | puerto ayora
# Processing City # 43 of 602 | roebourne
# Processing City # 44 of 602 | tsiroanomandidy
# Processing City # 45 of 602 | bengkulu
# city not found. skipping....
# Processing City # 46 of 602 | tuktoyaktuk
# Processing City # 47 of 602 | baoshan
# Processing City # 48 of 602 | carnarvon
# Processing City # 49 of 602 | honningsvag
# Processing City # 50 of 602 | skjervoy
# Processing City # 51 of 602 | boatlaname
# city not found. skipping....
# Processing City # 52 of 602 | palmer
# Processing City # 53 of 602 | hamilton
# Processing City # 54 of 602 | busselton
# Processing City # 55 of 602 | belushya guba
# city not found. skipping....
# Processing City # 56 of 602 | ketchikan
# Processing City # 57 of 602 | pevek
# Processing City # 58 of 602 | kuche
# city not found. skipping....
# Processing City # 59 of 602 | coquimbo
# Processing City # 60 of 602 | mataura
# Processing City # 61 of 602 | vaini
# Processing City # 62 of 602 | ilhabela
# Processing City # 63 of 602 | leningradskiy
# Processing City # 64 of 602 | hobart
# Processing City # 65 of 602 | guicheng
# city not found. skipping....
# Processing City # 66 of 602 | hasaki
# Processing City # 67 of 602 | klaksvik
# Processing City # 68 of 602 | lorengau
# Processing City # 69 of 602 | kapaa
# Processing City # 70 of 602 | luancheng
# Processing City # 71 of 602 | novyy urgal
# Processing City # 72 of 602 | luena
# Processing City # 73 of 602 | saint-philippe
# Processing City # 74 of 602 | taltal
# Processing City # 75 of 602 | aklavik
# Processing City # 76 of 602 | cape town
# Processing City # 77 of 602 | plettenberg bay
# Processing City # 78 of 602 | yarkovo
# Processing City # 79 of 602 | nikolskoye
# Processing City # 80 of 602 | bressanone
# Processing City # 81 of 602 | iqaluit
# Processing City # 82 of 602 | airai
# Processing City # 83 of 602 | araguaina
# Processing City # 84 of 602 | ciras
# city not found. skipping....
# Processing City # 85 of 602 | moosomin
# Processing City # 86 of 602 | codrington
# Processing City # 87 of 602 | tabou
# Processing City # 88 of 602 | mar del plata
# Processing City # 89 of 602 | jiwani
# Processing City # 90 of 602 | tasiilaq
# Processing City # 91 of 602 | port-gentil
# Processing City # 92 of 602 | wanganui
# Processing City # 93 of 602 | castro
# Processing City # 94 of 602 | tabory
# Processing City # 95 of 602 | meadow lake
# Processing City # 96 of 602 | fortuna
# Processing City # 97 of 602 | harrisonville
# Processing City # 98 of 602 | khatanga
# Processing City # 99 of 602 | beringovskiy
# Processing City # 100 of 602 | halifax
# Processing City # 101 of 602 | hilo
# Processing City # 102 of 602 | kaitangata
# Processing City # 103 of 602 | los llanos de aridane
# Processing City # 104 of 602 | iguatu
# Processing City # 105 of 602 | bilma
# Processing City # 106 of 602 | deputatskiy
# Processing City # 107 of 602 | saldanha
# Processing City # 108 of 602 | lebu
# Processing City # 109 of 602 | hithadhoo
# Processing City # 110 of 602 | muravlenko
# Processing City # 111 of 602 | lata
# Processing City # 112 of 602 | padang
# Processing City # 113 of 602 | tshikapa
# Processing City # 114 of 602 | qaanaaq
# Processing City # 115 of 602 | takoradi
# Processing City # 116 of 602 | ixtapa
# Processing City # 117 of 602 | dikson
# Processing City # 118 of 602 | kuala lipis
# Processing City # 119 of 602 | safakulevo
# Processing City # 120 of 602 | lagoa
# Processing City # 121 of 602 | bluff
# Processing City # 122 of 602 | mahebourg
# Processing City # 123 of 602 | nabire
# Processing City # 124 of 602 | horasan
# Processing City # 125 of 602 | bac lieu
# city not found. skipping....
# Processing City # 126 of 602 | gaoua
# Processing City # 127 of 602 | mokrous
# Processing City # 128 of 602 | tsihombe
# city not found. skipping....
# Processing City # 129 of 602 | gulshat
# city not found. skipping....
# Processing City # 130 of 602 | sao filipe
# Processing City # 131 of 602 | mabaruma
# Processing City # 132 of 602 | oyonnax
# Processing City # 133 of 602 | thompson
# Processing City # 134 of 602 | grindavik
# Processing City # 135 of 602 | ponta do sol
# Processing City # 136 of 602 | severobaykalsk
# Processing City # 137 of 602 | palabuhanratu
# city not found. skipping....
# Processing City # 138 of 602 | demyansk
# Processing City # 139 of 602 | chuy
# Processing City # 140 of 602 | nizhneyansk
# city not found. skipping....
# Processing City # 141 of 602 | sola
# Processing City # 142 of 602 | san policarpo
# Processing City # 143 of 602 | alice springs
# Processing City # 144 of 602 | galgani
# city not found. skipping....
# Processing City # 145 of 602 | tungkang
# city not found. skipping....
# Processing City # 146 of 602 | alofi
# Processing City # 147 of 602 | mulchen
# Processing City # 148 of 602 | berlevag
# Processing City # 149 of 602 | puri
# Processing City # 150 of 602 | shakawe
# Processing City # 151 of 602 | solsvik
# city not found. skipping....
# Processing City # 152 of 602 | luderitz
# Processing City # 153 of 602 | newport
# Processing City # 154 of 602 | faanui
# Processing City # 155 of 602 | zhezkazgan
# Processing City # 156 of 602 | mys shmidta
# city not found. skipping....
# Processing City # 157 of 602 | barentsburg
# city not found. skipping....
# Processing City # 158 of 602 | avarua
# Processing City # 159 of 602 | bredasdorp
# Processing City # 160 of 602 | port lincoln
# Processing City # 161 of 602 | kruisfontein
# Processing City # 162 of 602 | roald
# Processing City # 163 of 602 | cayenne
# Processing City # 164 of 602 | saint-augustin
# Processing City # 165 of 602 | tiksi
# Processing City # 166 of 602 | neyshabur
# Processing City # 167 of 602 | makkaveyevo
# Processing City # 168 of 602 | mezen
# Processing City # 169 of 602 | victoria
# Processing City # 170 of 602 | lamu
# Processing City # 171 of 602 | samusu
# city not found. skipping....
# Processing City # 172 of 602 | thunder bay
# Processing City # 173 of 602 | dunedin
# Processing City # 174 of 602 | zhuanghe
# Processing City # 175 of 602 | ribeira grande
# Processing City # 176 of 602 | kupang
# Processing City # 177 of 602 | norman wells
# Processing City # 178 of 602 | hit
# Processing City # 179 of 602 | smolenka
# Processing City # 180 of 602 | ulagan
# Processing City # 181 of 602 | metsovon
# city not found. skipping....
# Processing City # 182 of 602 | nyurba
# Processing City # 183 of 602 | hervey bay
# Processing City # 184 of 602 | abnub
# Processing City # 185 of 602 | avera
# Processing City # 186 of 602 | jalu
# Processing City # 187 of 602 | beyneu
# Processing City # 188 of 602 | coolum beach
# Processing City # 189 of 602 | saskylakh
# Processing City # 190 of 602 | north platte
# Processing City # 191 of 602 | oksfjord
# Processing City # 192 of 602 | burns lake
# Processing City # 193 of 602 | osmena
# Processing City # 194 of 602 | tselinnoye
# Processing City # 195 of 602 | karauzyak
# city not found. skipping....
# Processing City # 196 of 602 | the pas
# Processing City # 197 of 602 | illoqqortoormiut
# city not found. skipping....
# Processing City # 198 of 602 | rio cuarto
# Processing City # 199 of 602 | flin flon
# Processing City # 200 of 602 | isangel
# Processing City # 201 of 602 | skalistyy
# city not found. skipping....
# Processing City # 202 of 602 | solnechnyy
# Processing City # 203 of 602 | labuhan
# Processing City # 204 of 602 | okhotsk
# Processing City # 205 of 602 | la ciotat
# Processing City # 206 of 602 | yamandu
# Processing City # 207 of 602 | ambilobe
# Processing City # 208 of 602 | cherskiy
# Processing City # 209 of 602 | srednekolymsk
# Processing City # 210 of 602 | puro
# Processing City # 211 of 602 | shubarkuduk
# Processing City # 212 of 602 | muros
# Processing City # 213 of 602 | monrovia
# Processing City # 214 of 602 | ancud
# Processing City # 215 of 602 | katsuura
# Processing City # 216 of 602 | ewa beach
# Processing City # 217 of 602 | yukhnov
# Processing City # 218 of 602 | tessalit
# Processing City # 219 of 602 | arlit
# Processing City # 220 of 602 | mao
# Processing City # 221 of 602 | qax
# Processing City # 222 of 602 | ahipara
# Processing City # 223 of 602 | sao felix do xingu
# Processing City # 224 of 602 | marawi
# Processing City # 225 of 602 | breytovo
# Processing City # 226 of 602 | praya
# Processing City # 227 of 602 | batagay-alyta
# Processing City # 228 of 602 | chake chake
# Processing City # 229 of 602 | poum
# Processing City # 230 of 602 | acapulco
# Processing City # 231 of 602 | tefe
# Processing City # 232 of 602 | grand river south east
# city not found. skipping....
# Processing City # 233 of 602 | lai
# Processing City # 234 of 602 | lodja
# Processing City # 235 of 602 | lukovetskiy
# Processing City # 236 of 602 | tautira
# Processing City # 237 of 602 | port said
# Processing City # 238 of 602 | teya
# Processing City # 239 of 602 | arraial do cabo
# Processing City # 240 of 602 | esperance
# Processing City # 241 of 602 | san andres
# Processing City # 242 of 602 | kukushtan
# Processing City # 243 of 602 | nicoya
# Processing City # 244 of 602 | mendoza
# Processing City # 245 of 602 | gizo
# Processing City # 246 of 602 | verkhnyaya inta
# Processing City # 247 of 602 | attawapiskat
# city not found. skipping....
# Processing City # 248 of 602 | atasu
# Processing City # 249 of 602 | longyearbyen
# Processing City # 250 of 602 | amderma
# city not found. skipping....
# Processing City # 251 of 602 | lasa
# Processing City # 252 of 602 | luanda
# Processing City # 253 of 602 | callaway
# Processing City # 254 of 602 | cockburn town
# Processing City # 255 of 602 | samarai
# Processing City # 256 of 602 | le port
# Processing City # 257 of 602 | pacific grove
# Processing City # 258 of 602 | bathurst
# Processing City # 259 of 602 | buraydah
# Processing City # 260 of 602 | artyk
# city not found. skipping....
# Processing City # 261 of 602 | nakhon sawan
# Processing City # 262 of 602 | kudahuvadhoo
# Processing City # 263 of 602 | lahij
# Processing City # 264 of 602 | lavrentiya
# Processing City # 265 of 602 | korla
# city not found. skipping....
# Processing City # 266 of 602 | kazalinsk
# city not found. skipping....
# Processing City # 267 of 602 | rebrikha
# Processing City # 268 of 602 | aguimes
# Processing City # 269 of 602 | zeya
# Processing City # 270 of 602 | kankon
# Processing City # 271 of 602 | barela
# Processing City # 272 of 602 | wenling
# Processing City # 273 of 602 | bonavista
# Processing City # 274 of 602 | katherine
# Processing City # 275 of 602 | borogontsy
# Processing City # 276 of 602 | marystown
# Processing City # 277 of 602 | dunmore town
# Processing City # 278 of 602 | salalah
# Processing City # 279 of 602 | sawtell
# Processing City # 280 of 602 | peniche
# Processing City # 281 of 602 | sarwar
# Processing City # 282 of 602 | felanitx
# Processing City # 283 of 602 | clyde river
# Processing City # 284 of 602 | popondetta
# Processing City # 285 of 602 | sozimskiy
# Processing City # 286 of 602 | la paz
# Processing City # 287 of 602 | ust-nera
# Processing City # 288 of 602 | kahului
# Processing City # 289 of 602 | zenzeli
# Processing City # 290 of 602 | zhaotong
# Processing City # 291 of 602 | sterling
# Processing City # 292 of 602 | hastings
# Processing City # 293 of 602 | cap-chat
# Processing City # 294 of 602 | beya
# Processing City # 295 of 602 | rujewa
# Processing City # 296 of 602 | coihaique
# Processing City # 297 of 602 | ca mau
# Processing City # 298 of 602 | murgab
# Processing City # 299 of 602 | zyryanka
# Processing City # 300 of 602 | cuamba
# Processing City # 301 of 602 | omsukchan
# Processing City # 302 of 602 | jinja
# Processing City # 303 of 602 | sentyabrskiy
# city not found. skipping....
# Processing City # 304 of 602 | bubaque
# Processing City # 305 of 602 | mrirt
# city not found. skipping....
# Processing City # 306 of 602 | andevoranto
# city not found. skipping....
# Processing City # 307 of 602 | axim
# Processing City # 308 of 602 | ankara
# Processing City # 309 of 602 | chitral
# Processing City # 310 of 602 | ginir
# Processing City # 311 of 602 | lusambo
# Processing City # 312 of 602 | bakau
# Processing City # 313 of 602 | caraballeda
# Processing City # 314 of 602 | constantine
# Processing City # 315 of 602 | richards bay
# Processing City # 316 of 602 | ormara
# Processing City # 317 of 602 | warqla
# city not found. skipping....
# Processing City # 318 of 602 | kodinar
# Processing City # 319 of 602 | tabiauea
# city not found. skipping....
# Processing City # 320 of 602 | road town
# Processing City # 321 of 602 | caianu mic
# Processing City # 322 of 602 | malwan
# city not found. skipping....
# Processing City # 323 of 602 | belawan
# Processing City # 324 of 602 | walvis bay
# Processing City # 325 of 602 | la ronge
# Processing City # 326 of 602 | puerto escondido
# Processing City # 327 of 602 | abu samrah
# Processing City # 328 of 602 | jardim
# Processing City # 329 of 602 | makung
# city not found. skipping....
# Processing City # 330 of 602 | kapustin yar-1
# city not found. skipping....
# Processing City # 331 of 602 | hua hin
# Processing City # 332 of 602 | mogadishu
# Processing City # 333 of 602 | harper
# Processing City # 334 of 602 | sebina
# Processing City # 335 of 602 | prince rupert
# Processing City # 336 of 602 | warrnambool
# Processing City # 337 of 602 | belyy yar
# Processing City # 338 of 602 | gravdal
# Processing City # 339 of 602 | iturama
# Processing City # 340 of 602 | praia da vitoria
# Processing City # 341 of 602 | hohhot
# Processing City # 342 of 602 | naze
# Processing City # 343 of 602 | cabo san lucas
# Processing City # 344 of 602 | sabha
# Processing City # 345 of 602 | hvide sande
# Processing City # 346 of 602 | guerrero negro
# Processing City # 347 of 602 | nanortalik
# Processing City # 348 of 602 | geraldton
# Processing City # 349 of 602 | komsomolskiy
# Processing City # 350 of 602 | broome
# Processing City # 351 of 602 | kodiak
# Processing City # 352 of 602 | riyadh
# Processing City # 353 of 602 | wageningen
# Processing City # 354 of 602 | rorvik
# Processing City # 355 of 602 | ostersund
# Processing City # 356 of 602 | strathmore
# Processing City # 357 of 602 | kirensk
# Processing City # 358 of 602 | manzil tamim
# city not found. skipping....
# Processing City # 359 of 602 | vaitape
# Processing City # 360 of 602 | karamay
# city not found. skipping....
# Processing City # 361 of 602 | caceres
# Processing City # 362 of 602 | manggar
# Processing City # 363 of 602 | henties bay
# Processing City # 364 of 602 | bodden town
# Processing City # 365 of 602 | maceio
# Processing City # 366 of 602 | saint-denis
# Processing City # 367 of 602 | east chicago
# Processing City # 368 of 602 | saleaula
# city not found. skipping....
# Processing City # 369 of 602 | sorvag
# city not found. skipping....
# Processing City # 370 of 602 | aykhal
# Processing City # 371 of 602 | kibala
# Processing City # 372 of 602 | tigil
# Processing City # 373 of 602 | eskasem
# city not found. skipping....
# Processing City # 374 of 602 | sao francisco do sul
# Processing City # 375 of 602 | frumusica
# Processing City # 376 of 602 | carupano
# Processing City # 377 of 602 | louisbourg
# city not found. skipping....
# Processing City # 378 of 602 | qaqortoq
# Processing City # 379 of 602 | auray
# Processing City # 380 of 602 | inhambane
# Processing City # 381 of 602 | kutum
# Processing City # 382 of 602 | lalibela
# Processing City # 383 of 602 | faya
# Processing City # 384 of 602 | maniitsoq
# Processing City # 385 of 602 | petropavlovka
# Processing City # 386 of 602 | tura
# Processing City # 387 of 602 | salyan
# Processing City # 388 of 602 | west plains
# Processing City # 389 of 602 | dongzhen
# Processing City # 390 of 602 | huainan
# Processing City # 391 of 602 | san juan
# Processing City # 392 of 602 | maldonado
# Processing City # 393 of 602 | palmas bellas
# Processing City # 394 of 602 | vila
# Processing City # 395 of 602 | corinth
# Processing City # 396 of 602 | lyuban
# Processing City # 397 of 602 | sioux lookout
# Processing City # 398 of 602 | villarrica
# Processing City # 399 of 602 | general cepeda
# Processing City # 400 of 602 | pocoes
# Processing City # 401 of 602 | comodoro rivadavia
# Processing City # 402 of 602 | lanester
# Processing City # 403 of 602 | asyut
# Processing City # 404 of 602 | viedma
# Processing City # 405 of 602 | kholm
# Processing City # 406 of 602 | necochea
# Processing City # 407 of 602 | copala
# Processing City # 408 of 602 | el alto
# Processing City # 409 of 602 | zheleznodorozhnyy
# Processing City # 410 of 602 | jackson
# Processing City # 411 of 602 | vila franca do campo
# Processing City # 412 of 602 | kyshtovka
# Processing City # 413 of 602 | russell
# Processing City # 414 of 602 | mahon
# Processing City # 415 of 602 | yar-sale
# Processing City # 416 of 602 | hualmay
# Processing City # 417 of 602 | sosnogorsk
# Processing City # 418 of 602 | zacualtipan
# Processing City # 419 of 602 | ingleside
# Processing City # 420 of 602 | auki
# Processing City # 421 of 602 | washington
# Processing City # 422 of 602 | kenai
# Processing City # 423 of 602 | hwange
# Processing City # 424 of 602 | sabang
# Processing City # 425 of 602 | marzuq
# Processing City # 426 of 602 | rio gallegos
# Processing City # 427 of 602 | saint-pierre
# Processing City # 428 of 602 | nuuk
# Processing City # 429 of 602 | moose factory
# Processing City # 430 of 602 | kargasok
# Processing City # 431 of 602 | ahuimanu
# Processing City # 432 of 602 | honiara
# Processing City # 433 of 602 | port macquarie
# Processing City # 434 of 602 | dali
# Processing City # 435 of 602 | canaries
# city not found. skipping....
# Processing City # 436 of 602 | daru
# Processing City # 437 of 602 | ijaki
# city not found. skipping....
# Processing City # 438 of 602 | hovd
# Processing City # 439 of 602 | bandiagara
# Processing City # 440 of 602 | hunchun
# Processing City # 441 of 602 | kosh-agach
# Processing City # 442 of 602 | huarmey
# Processing City # 443 of 602 | tangwani
# Processing City # 444 of 602 | kalachinsk
# Processing City # 445 of 602 | orlik
# Processing City # 446 of 602 | evensk
# Processing City # 447 of 602 | ugoofaaru
# Processing City # 448 of 602 | daxian
# city not found. skipping....
# Processing City # 449 of 602 | puerto madryn
# Processing City # 450 of 602 | huilong
# Processing City # 451 of 602 | kinsale
# Processing City # 452 of 602 | bucerias
# Processing City # 453 of 602 | pisco
# Processing City # 454 of 602 | gusau
# Processing City # 455 of 602 | kapit
# Processing City # 456 of 602 | port hedland
# Processing City # 457 of 602 | westport
# Processing City # 458 of 602 | san isidro
# Processing City # 459 of 602 | bengbu
# Processing City # 460 of 602 | cabedelo
# Processing City # 461 of 602 | menongue
# Processing City # 462 of 602 | quelimane
# Processing City # 463 of 602 | fremont
# Processing City # 464 of 602 | tazovskiy
# Processing City # 465 of 602 | igarka
# Processing City # 466 of 602 | marsh harbour
# Processing City # 467 of 602 | te anau
# Processing City # 468 of 602 | tongzi
# Processing City # 469 of 602 | ossora
# Processing City # 470 of 602 | ilulissat
# Processing City # 471 of 602 | batagay
# Processing City # 472 of 602 | candido mota
# Processing City # 473 of 602 | kuusamo
# Processing City # 474 of 602 | carballo
# Processing City # 475 of 602 | inderborskiy
# city not found. skipping....
# Processing City # 476 of 602 | tuatapere
# Processing City # 477 of 602 | gamba
# Processing City # 478 of 602 | dusti
# Processing City # 479 of 602 | katha
# city not found. skipping....
# Processing City # 480 of 602 | nouadhibou
# Processing City # 481 of 602 | humberto de campos
# Processing City # 482 of 602 | lafia
# Processing City # 483 of 602 | tuensang
# Processing City # 484 of 602 | belaya gora
# Processing City # 485 of 602 | karaul
# city not found. skipping....
# Processing City # 486 of 602 | flinders
# Processing City # 487 of 602 | choucheng
# city not found. skipping....
# Processing City # 488 of 602 | sredniy ikorets
# Processing City # 489 of 602 | borba
# Processing City # 490 of 602 | sengiley
# Processing City # 491 of 602 | baruun-urt
# Processing City # 492 of 602 | fukue
# Processing City # 493 of 602 | aktas
# city not found. skipping....
# Processing City # 494 of 602 | narsaq
# Processing City # 495 of 602 | khani
# Processing City # 496 of 602 | mpika
# Processing City # 497 of 602 | osorno
# Processing City # 498 of 602 | bhilwara
# Processing City # 499 of 602 | donji vakuf
# Processing City # 500 of 602 | varhaug
# Processing City # 501 of 602 | grande prairie
# Processing City # 502 of 602 | malakal
# city not found. skipping....
# Processing City # 503 of 602 | axixa do tocantins
# city not found. skipping....
# Processing City # 504 of 602 | columbus
# Processing City # 505 of 602 | acari
# Processing City # 506 of 602 | bud
# Processing City # 507 of 602 | suchil
# Processing City # 508 of 602 | amberley
# Processing City # 509 of 602 | vila velha
# Processing City # 510 of 602 | neumunster
# Processing City # 511 of 602 | kemin
# Processing City # 512 of 602 | mackay
# Processing City # 513 of 602 | alyangula
# Processing City # 514 of 602 | dzaoudzi
# Processing City # 515 of 602 | daloa
# Processing City # 516 of 602 | khandyga
# Processing City # 517 of 602 | tateyama
# Processing City # 518 of 602 | nyrob
# Processing City # 519 of 602 | sadiqabad
# Processing City # 520 of 602 | petropavlovsk-kamchatskiy
# Processing City # 521 of 602 | chernyshevskiy
# Processing City # 522 of 602 | pedernales
# Processing City # 523 of 602 | hofn
# Processing City # 524 of 602 | meulaboh
# Processing City # 525 of 602 | ciudad bolivar
# Processing City # 526 of 602 | sharjah
# Processing City # 527 of 602 | marcona
# city not found. skipping....
# Processing City # 528 of 602 | pemba
# Processing City # 529 of 602 | paradwip
# city not found. skipping....
# Processing City # 530 of 602 | awbari
# Processing City # 531 of 602 | innisfail
# Processing City # 532 of 602 | yuli
# Processing City # 533 of 602 | znamenskoye
# Processing City # 534 of 602 | abha
# Processing City # 535 of 602 | jaslo
# Processing City # 536 of 602 | vao
# Processing City # 537 of 602 | predivinsk
# Processing City # 538 of 602 | tecoanapa
# Processing City # 539 of 602 | salinopolis
# Processing City # 540 of 602 | rondon
# Processing City # 541 of 602 | hirado
# Processing City # 542 of 602 | severo-kurilsk
# Processing City # 543 of 602 | safwah
# city not found. skipping....
# Processing City # 544 of 602 | marquette
# Processing City # 545 of 602 | paysandu
# Processing City # 546 of 602 | galiwinku
# city not found. skipping....
# Processing City # 547 of 602 | camrose
# Processing City # 548 of 602 | chardara
# city not found. skipping....
# Processing City # 549 of 602 | vestmanna
# Processing City # 550 of 602 | haibowan
# city not found. skipping....
# Processing City # 551 of 602 | balabac
# Processing City # 552 of 602 | zonguldak
# Processing City # 553 of 602 | taoudenni
# Processing City # 554 of 602 | galdar
# Processing City # 555 of 602 | provost
# Processing City # 556 of 602 | sigiriya
# Processing City # 557 of 602 | ipixuna
# Processing City # 558 of 602 | stei
# city not found. skipping....
# Processing City # 559 of 602 | bandarbeyla
# Processing City # 560 of 602 | itarema
# Processing City # 561 of 602 | ullapool
# Processing City # 562 of 602 | souillac
# Processing City # 563 of 602 | kachikau
# city not found. skipping....
# Processing City # 564 of 602 | mantamados
# Processing City # 565 of 602 | sorland
# Processing City # 566 of 602 | sorong
# Processing City # 567 of 602 | whitehorse
# Processing City # 568 of 602 | chilca
# Processing City # 569 of 602 | yatou
# Processing City # 570 of 602 | santa cruz
# Processing City # 571 of 602 | acajutla
# Processing City # 572 of 602 | ongandjera
# Processing City # 573 of 602 | oskarshamn
# Processing City # 574 of 602 | provideniya
# Processing City # 575 of 602 | husavik
# Processing City # 576 of 602 | havre
# Processing City # 577 of 602 | vysokogornyy
# Processing City # 578 of 602 | olafsvik
# city not found. skipping....
# Processing City # 579 of 602 | mitsamiouli
# Processing City # 580 of 602 | anloga
# Processing City # 581 of 602 | kieta
# Processing City # 582 of 602 | qarqin
# Processing City # 583 of 602 | rochester
# Processing City # 584 of 602 | atar
# Processing City # 585 of 602 | sumbe
# Processing City # 586 of 602 | koupela
# Processing City # 587 of 602 | santa rosa del sur
# Processing City # 588 of 602 | kitgum
# Processing City # 589 of 602 | liku
# Processing City # 590 of 602 | vostok
# Processing City # 591 of 602 | nome
# Processing City # 592 of 602 | portland
# Processing City # 593 of 602 | romans-sur-isere
# Processing City # 594 of 602 | yuci
# Processing City # 595 of 602 | torbay
# Processing City # 596 of 602 | casas grandes
# Processing City # 597 of 602 | zhemchuzhnyy
# city not found. skipping....
# Processing City # 598 of 602 | erenhot
# Processing City # 599 of 602 | tias
# Processing City # 600 of 602 | lichinga
# Processing City # 601 of 602 | vilyuysk
# Processing City # 602 of 602 | mount pleasant
# Processing City # 603 of 602 | ibra
# Processing City # 604 of 602 | ternate
# Processing City # 605 of 602 | guatire
# Processing City # 606 of 602 | luwuk
# Processing City # 607 of 602 | namatanai
# Processing City # 608 of 602 | chapais
# Processing City # 609 of 602 | pangnirtung

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#combine all of the lists
df = {'City': city_list, 'Cloudiness':cloudiness , 'Country':country, 'Date':date, 'Humidity':humidity, 'Lat':lat, 'Lng':lng, 
      'Max Temp':maxtemp, 'Wind Speed':windspeed}

# %%
#create a dataframe
df = pd.DataFrame(data = df)

# %%
#double check the tranformation
df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0   hambantota           0      LK  1553019000       100   6.12  81.12
# 1       olinda          75      EC  1553021718        78  -2.03 -79.75
# 2  port alfred           0      ZA  1553021773        95 -33.59  26.89
# 3     matagami           0      NG  1553021801        27   9.67   8.40
# 4     hermanus          92      ZA  1553021189        93 -34.42  19.24
#
#    Max Temp  Wind Speed
# 0     77.00       11.79
# 1     84.00        9.17
# 2     68.00        1.99
# 3     84.11        4.18
# 4     66.99        3.00

# %%
#check total data points, 543
df.count()
# Out:
# City          543
# Cloudiness    543
# Country       543
# Date          543
# Humidity      543
# Lat           543
# Lng           543
# Max Temp      543
# Wind Speed    543
# dtype: int64

# %%
#export to excel
df.to_csv("Weather_Data.csv", encoding="utf-8",header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df['Lat'], df['Max Temp'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Max Temp ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (f)')
plt.grid()
plt.savefig('Latitude_vs_MaxTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df['Lat'], df['Humidity'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Humidity ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Humidity (%)')
plt.ylim(top=105) #ylim set to 100 as there was one mistake in a city entry with 300% humidity
plt.grid()
plt.savefig('Latitude_vs_Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Lat'], df['Cloudiness'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%m/%d/%y')})")
plt.xlabel('City Latitude') 
plt.ylabel('Cloudiness(%)')
plt.grid()
plt.savefig('Latitude_vs_Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Lat'], df['Wind Speed'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%m/%d/%y')})")
plt.xlabel('City Latitude') 
plt.ylabel('Wind Speed(mph)')
plt.ylim(bottom = -1, top=45) #ylim set lower as there was one outlier which threw off the plot
plt.grid()
plt.savefig('Latitude_vs_Wind Speed.png')

# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There does not seem to be a very strong correlation between latitude and humidity but there does seem to be slightly more cities to the North with lower humidity compared to South of the equator.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0 and 78% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
cities2 = cities[0:20]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Base URL
url = 'http://api.openweathermap.org/data/2.5/weather?q='

#make empty lists to fill with the data from the API website
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []
city_list = []
counter = 1
        
# Get weather data
for city in cities:
    
    try:
        print(f'Processing City # {counter} of 602 | {city}')
        query = requests.get(url + city + '&units=imperial' +'&APPID='+ api_key).json()
        cloudiness.append(query['clouds']['all'])
        city_list.append(city)
        country.append(query['sys']['country'])
        date.append(query['dt'])
        humidity.append(query['main']['humidity'])
        lat.append(query['coord']['lat'])
        lng.append(query['coord']['lat'])
        maxtemp.append(query['main']['temp_max'])
        windspeed.append(query['wind']['speed'])
        
        
    except KeyError:
        print('city not found. skipping....') 
        pass
    
    counter += 1
# Out:
# Processing City # 1 of 602 | aklavik
# Processing City # 2 of 602 | kapit
# Processing City # 3 of 602 | hermanus
# Processing City # 4 of 602 | belushya guba
# city not found. skipping....
# Processing City # 5 of 602 | vilhena
# Processing City # 6 of 602 | georgetown
# Processing City # 7 of 602 | ponta do sol
# Processing City # 8 of 602 | byron bay
# Processing City # 9 of 602 | dikson
# Processing City # 10 of 602 | bani
# Processing City # 11 of 602 | provideniya
# Processing City # 12 of 602 | bluff
# Processing City # 13 of 602 | port alfred
# Processing City # 14 of 602 | dhidhdhoo
# Processing City # 15 of 602 | vila franca do campo
# Processing City # 16 of 602 | tiksi
# Processing City # 17 of 602 | jamestown
# Processing City # 18 of 602 | ushuaia
# Processing City # 19 of 602 | cape town
# Processing City # 20 of 602 | haverfordwest
# Processing City # 21 of 602 | butaritari
# Processing City # 22 of 602 | punta arenas
# Processing City # 23 of 602 | pevek
# Processing City # 24 of 602 | airai
# Processing City # 25 of 602 | vaini
# Processing City # 26 of 602 | bengkulu
# city not found. skipping....
# Processing City # 27 of 602 | new norfolk
# Processing City # 28 of 602 | marawi
# Processing City # 29 of 602 | khatanga
# Processing City # 30 of 602 | lebu
# Processing City # 31 of 602 | saint-philippe
# Processing City # 32 of 602 | torbay
# Processing City # 33 of 602 | puerto ayora
# Processing City # 34 of 602 | meridian
# Processing City # 35 of 602 | aguimes
# Processing City # 36 of 602 | vaitupu
# city not found. skipping....
# Processing City # 37 of 602 | wanning
# Processing City # 38 of 602 | victoria
# Processing City # 39 of 602 | albany
# Processing City # 40 of 602 | tuatapere
# Processing City # 41 of 602 | kavieng
# Processing City # 42 of 602 | iskateley
# Processing City # 43 of 602 | saint anthony
# Processing City # 44 of 602 | mazamari
# Processing City # 45 of 602 | norman wells
# Processing City # 46 of 602 | barrow
# Processing City # 47 of 602 | mahanje
# city not found. skipping....
# Processing City # 48 of 602 | mehamn
# Processing City # 49 of 602 | leningradskiy
# Processing City # 50 of 602 | saskylakh
# Processing City # 51 of 602 | sovetskiy
# Processing City # 52 of 602 | viligili
# city not found. skipping....
# Processing City # 53 of 602 | mezen
# Processing City # 54 of 602 | kisangani
# Processing City # 55 of 602 | avarua
# Processing City # 56 of 602 | marau
# Processing City # 57 of 602 | kahului
# Processing City # 58 of 602 | coos bay
# Processing City # 59 of 602 | hilo
# Processing City # 60 of 602 | voh
# Processing City # 61 of 602 | poum
# Processing City # 62 of 602 | naze
# Processing City # 63 of 602 | attawapiskat
# city not found. skipping....
# Processing City # 64 of 602 | clyde river
# Processing City # 65 of 602 | lieksa
# Processing City # 66 of 602 | laizhou
# Processing City # 67 of 602 | staryy nadym
# Processing City # 68 of 602 | rikitea
# Processing City # 69 of 602 | ridgecrest
# Processing City # 70 of 602 | mataura
# Processing City # 71 of 602 | adrar
# Processing City # 72 of 602 | broome
# Processing City # 73 of 602 | faanui
# Processing City # 74 of 602 | colares
# Processing City # 75 of 602 | bredasdorp
# Processing City # 76 of 602 | busselton
# Processing City # 77 of 602 | ostersund
# Processing City # 78 of 602 | cherskiy
# Processing City # 79 of 602 | belyy yar
# Processing City # 80 of 602 | inhambane
# Processing City # 81 of 602 | lotofaga
# Processing City # 82 of 602 | port elizabeth
# Processing City # 83 of 602 | nizhneyansk
# city not found. skipping....
# Processing City # 84 of 602 | zhigansk
# Processing City # 85 of 602 | qaanaaq
# Processing City # 86 of 602 | qatana
# Processing City # 87 of 602 | kulhudhuffushi
# Processing City # 88 of 602 | shingu
# Processing City # 89 of 602 | lao cai
# Processing City # 90 of 602 | kapaa
# Processing City # 91 of 602 | kokstad
# Processing City # 92 of 602 | safaqis
# city not found. skipping....
# Processing City # 93 of 602 | kaabong
# Processing City # 94 of 602 | tasbuget
# city not found. skipping....
# Processing City # 95 of 602 | plainview
# Processing City # 96 of 602 | mount gambier
# Processing City # 97 of 602 | lala
# Processing City # 98 of 602 | piove di sacco
# Processing City # 99 of 602 | puerto leguizamo
# Processing City # 100 of 602 | sentyabrskiy
# city not found. skipping....
# Processing City # 101 of 602 | marang
# city not found. skipping....
# Processing City # 102 of 602 | ati
# Processing City # 103 of 602 | belmonte
# Processing City # 104 of 602 | tuktoyaktuk
# Processing City # 105 of 602 | caravelas
# Processing City # 106 of 602 | tsihombe
# city not found. skipping....
# Processing City # 107 of 602 | half moon bay
# Processing City # 108 of 602 | itaituba
# Processing City # 109 of 602 | eyl
# Processing City # 110 of 602 | sawtell
# Processing City # 111 of 602 | cabo rojo
# Processing City # 112 of 602 | margate
# Processing City # 113 of 602 | batticaloa
# Processing City # 114 of 602 | antofagasta
# Processing City # 115 of 602 | australind
# Processing City # 116 of 602 | barentsburg
# city not found. skipping....
# Processing City # 117 of 602 | clemencia
# Processing City # 118 of 602 | jieshi
# Processing City # 119 of 602 | richards bay
# Processing City # 120 of 602 | lubao
# Processing City # 121 of 602 | taolanaro
# city not found. skipping....
# Processing City # 122 of 602 | illoqqortoormiut
# city not found. skipping....
# Processing City # 123 of 602 | lodja
# Processing City # 124 of 602 | traunreut
# Processing City # 125 of 602 | mahebourg
# Processing City # 126 of 602 | balykshi
# city not found. skipping....
# Processing City # 127 of 602 | lazaro cardenas
# Processing City # 128 of 602 | tasiilaq
# Processing City # 129 of 602 | carnarvon
# Processing City # 130 of 602 | pansemal
# Processing City # 131 of 602 | puerto baquerizo moreno
# Processing City # 132 of 602 | shimoda
# Processing City # 133 of 602 | sakakah
# city not found. skipping....
# Processing City # 134 of 602 | aden
# Processing City # 135 of 602 | samusu
# city not found. skipping....
# Processing City # 136 of 602 | qujing
# Processing City # 137 of 602 | umzimvubu
# city not found. skipping....
# Processing City # 138 of 602 | constitucion
# Processing City # 139 of 602 | ladozhskaya
# Processing City # 140 of 602 | lokosovo
# Processing City # 141 of 602 | saldanha
# Processing City # 142 of 602 | ribeira grande
# Processing City # 143 of 602 | yellowknife
# Processing City # 144 of 602 | astipalaia
# city not found. skipping....
# Processing City # 145 of 602 | san quintin
# Processing City # 146 of 602 | saleaula
# city not found. skipping....
# Processing City # 147 of 602 | wajima
# Processing City # 148 of 602 | brigham city
# Processing City # 149 of 602 | severo-kurilsk
# Processing City # 150 of 602 | bethel
# Processing City # 151 of 602 | kalmunai
# Processing City # 152 of 602 | saint-pierre
# Processing City # 153 of 602 | mount isa
# Processing City # 154 of 602 | hobart
# Processing City # 155 of 602 | hithadhoo
# Processing City # 156 of 602 | nanzhou
# Processing City # 157 of 602 | esperance
# Processing City # 158 of 602 | cidreira
# Processing City # 159 of 602 | biltine
# Processing City # 160 of 602 | atuona
# Processing City # 161 of 602 | pathein
# Processing City # 162 of 602 | castro
# Processing City # 163 of 602 | hambantota
# Processing City # 164 of 602 | san cristobal
# Processing City # 165 of 602 | butembo
# Processing City # 166 of 602 | salta
# Processing City # 167 of 602 | narsaq
# Processing City # 168 of 602 | strezhevoy
# Processing City # 169 of 602 | ostrovnoy
# Processing City # 170 of 602 | gat
# Processing City # 171 of 602 | dahuk
# city not found. skipping....
# Processing City # 172 of 602 | san rafael
# Processing City # 173 of 602 | balabac
# Processing City # 174 of 602 | sarangani
# Processing City # 175 of 602 | iqaluit
# Processing City # 176 of 602 | dawei
# Processing City # 177 of 602 | kodiak
# Processing City # 178 of 602 | ballina
# Processing City # 179 of 602 | anadyr
# Processing City # 180 of 602 | nicoya
# Processing City # 181 of 602 | port-gentil
# Processing City # 182 of 602 | andra
# Processing City # 183 of 602 | nanortalik
# Processing City # 184 of 602 | bolshiye uki
# city not found. skipping....
# Processing City # 185 of 602 | hualmay
# Processing City # 186 of 602 | grand river south east
# city not found. skipping....
# Processing City # 187 of 602 | jacksonville
# Processing City # 188 of 602 | kaliningrad
# Processing City # 189 of 602 | itamarandiba
# Processing City # 190 of 602 | kishi
# Processing City # 191 of 602 | kaitangata
# Processing City # 192 of 602 | amderma
# city not found. skipping....
# Processing City # 193 of 602 | sao filipe
# Processing City # 194 of 602 | bilibino
# Processing City # 195 of 602 | upernavik
# Processing City # 196 of 602 | hasaki
# Processing City # 197 of 602 | kankon
# Processing City # 198 of 602 | rungata
# city not found. skipping....
# Processing City # 199 of 602 | deputatskiy
# Processing City # 200 of 602 | verkhnyaya inta
# Processing City # 201 of 602 | bayir
# Processing City # 202 of 602 | vagur
# Processing City # 203 of 602 | avera
# Processing City # 204 of 602 | takoradi
# Processing City # 205 of 602 | yerbogachen
# Processing City # 206 of 602 | vardo
# Processing City # 207 of 602 | ucluelet
# Processing City # 208 of 602 | longlac
# city not found. skipping....
# Processing City # 209 of 602 | mackay
# Processing City # 210 of 602 | revelstoke
# Processing City # 211 of 602 | te anau
# Processing City # 212 of 602 | taoudenni
# Processing City # 213 of 602 | montlucon
# Processing City # 214 of 602 | chuy
# Processing City # 215 of 602 | mys shmidta
# city not found. skipping....
# Processing City # 216 of 602 | el rosario
# Processing City # 217 of 602 | luderitz
# Processing City # 218 of 602 | souillac
# Processing City # 219 of 602 | santa cruz
# Processing City # 220 of 602 | te horo
# Processing City # 221 of 602 | bubaque
# Processing City # 222 of 602 | veraval
# Processing City # 223 of 602 | north platte
# Processing City # 224 of 602 | bonfim
# Processing City # 225 of 602 | east london
# Processing City # 226 of 602 | port blair
# Processing City # 227 of 602 | elizabeth city
# Processing City # 228 of 602 | sur
# Processing City # 229 of 602 | benguela
# Processing City # 230 of 602 | newport
# Processing City # 231 of 602 | cabo san lucas
# Processing City # 232 of 602 | ouadda
# Processing City # 233 of 602 | batagay
# Processing City # 234 of 602 | isangel
# Processing City # 235 of 602 | antequera
# Processing City # 236 of 602 | devyatka
# city not found. skipping....
# Processing City # 237 of 602 | whitehorse
# Processing City # 238 of 602 | port macquarie
# Processing City # 239 of 602 | los llanos de aridane
# Processing City # 240 of 602 | tiznit
# Processing City # 241 of 602 | pangkalanbuun
# Processing City # 242 of 602 | yuncheng
# Processing City # 243 of 602 | santa isabel do rio negro
# Processing City # 244 of 602 | beringovskiy
# Processing City # 245 of 602 | kloulklubed
# Processing City # 246 of 602 | meyungs
# city not found. skipping....
# Processing City # 247 of 602 | calbuco
# Processing City # 248 of 602 | bulgan
# Processing City # 249 of 602 | saint-honore
# city not found. skipping....
# Processing City # 250 of 602 | cholet
# Processing City # 251 of 602 | ngukurr
# city not found. skipping....
# Processing City # 252 of 602 | la palma
# Processing City # 253 of 602 | kishtwar
# Processing City # 254 of 602 | saint george
# Processing City # 255 of 602 | kalabo
# Processing City # 256 of 602 | neuquen
# Processing City # 257 of 602 | kassala
# Processing City # 258 of 602 | waipawa
# Processing City # 259 of 602 | salinopolis
# Processing City # 260 of 602 | zhuanghe
# Processing City # 261 of 602 | longyearbyen
# Processing City # 262 of 602 | liverpool
# Processing City # 263 of 602 | puerto colombia
# Processing City # 264 of 602 | tillabery
# city not found. skipping....
# Processing City # 265 of 602 | lolua
# city not found. skipping....
# Processing City # 266 of 602 | ahipara
# Processing City # 267 of 602 | kruisfontein
# Processing City # 268 of 602 | ahlat
# Processing City # 269 of 602 | lavrentiya
# Processing City # 270 of 602 | porto empedocle
# Processing City # 271 of 602 | lagoa
# Processing City # 272 of 602 | lompoc
# Processing City # 273 of 602 | tabuk
# Processing City # 274 of 602 | guerrero negro
# Processing City # 275 of 602 | geraldton
# Processing City # 276 of 602 | sao felix do xingu
# Processing City # 277 of 602 | huarmey
# Processing City # 278 of 602 | amalapuram
# Processing City # 279 of 602 | dunedin
# Processing City # 280 of 602 | vanimo
# Processing City # 281 of 602 | liepaja
# Processing City # 282 of 602 | sola
# Processing City # 283 of 602 | nambucca heads
# Processing City # 284 of 602 | kota
# Processing City # 285 of 602 | mayumba
# Processing City # 286 of 602 | garowe
# Processing City # 287 of 602 | merrill
# Processing City # 288 of 602 | hovd
# Processing City # 289 of 602 | abu samrah
# Processing City # 290 of 602 | arraial do cabo
# Processing City # 291 of 602 | thompson
# Processing City # 292 of 602 | thunder bay
# Processing City # 293 of 602 | awjilah
# Processing City # 294 of 602 | yongan
# Processing City # 295 of 602 | itarema
# Processing City # 296 of 602 | kumluca
# Processing City # 297 of 602 | necochea
# Processing City # 298 of 602 | mar del plata
# Processing City # 299 of 602 | madison heights
# Processing City # 300 of 602 | chokurdakh
# Processing City # 301 of 602 | hanford
# Processing City # 302 of 602 | bambous virieux
# Processing City # 303 of 602 | san lorenzo
# Processing City # 304 of 602 | kogon
# Processing City # 305 of 602 | gladstone
# Processing City # 306 of 602 | porto novo
# Processing City # 307 of 602 | urengoy
# Processing City # 308 of 602 | williston
# Processing City # 309 of 602 | tramore
# Processing City # 310 of 602 | nantucket
# Processing City # 311 of 602 | castilho
# Processing City # 312 of 602 | cabedelo
# Processing City # 313 of 602 | acari
# Processing City # 314 of 602 | luba
# Processing City # 315 of 602 | port hedland
# Processing City # 316 of 602 | nome
# Processing City # 317 of 602 | high level
# Processing City # 318 of 602 | maniitsoq
# Processing City # 319 of 602 | tondano
# Processing City # 320 of 602 | nelson bay
# Processing City # 321 of 602 | simao
# Processing City # 322 of 602 | linxia
# Processing City # 323 of 602 | balkanabat
# Processing City # 324 of 602 | grand gaube
# Processing City # 325 of 602 | agadir
# Processing City # 326 of 602 | aswan
# Processing City # 327 of 602 | tabiauea
# city not found. skipping....
# Processing City # 328 of 602 | gasa
# Processing City # 329 of 602 | neiafu
# Processing City # 330 of 602 | lasa
# Processing City # 331 of 602 | burnie
# Processing City # 332 of 602 | tautira
# Processing City # 333 of 602 | zlatoustovsk
# city not found. skipping....
# Processing City # 334 of 602 | owo
# Processing City # 335 of 602 | erzin
# Processing City # 336 of 602 | cap malheureux
# Processing City # 337 of 602 | mahajanga
# Processing City # 338 of 602 | yar-sale
# Processing City # 339 of 602 | louisbourg
# city not found. skipping....
# Processing City # 340 of 602 | dingle
# Processing City # 341 of 602 | dori
# Processing City # 342 of 602 | surt
# Processing City # 343 of 602 | baherden
# Processing City # 344 of 602 | ghanzi
# Processing City # 345 of 602 | bianzhuang
# Processing City # 346 of 602 | ilulissat
# Processing City # 347 of 602 | kampong thum
# Processing City # 348 of 602 | pangnirtung
# Processing City # 349 of 602 | dingzhou
# Processing City # 350 of 602 | kiruna
# Processing City # 351 of 602 | coquimbo
# Processing City # 352 of 602 | marzuq
# Processing City # 353 of 602 | benghazi
# Processing City # 354 of 602 | san patricio
# Processing City # 355 of 602 | nikolskoye
# Processing City # 356 of 602 | orangeburg
# Processing City # 357 of 602 | muli
# Processing City # 358 of 602 | freetown
# Processing City # 359 of 602 | corbelia
# Processing City # 360 of 602 | suluq
# Processing City # 361 of 602 | san vicente
# Processing City # 362 of 602 | haines junction
# Processing City # 363 of 602 | rabo de peixe
# Processing City # 364 of 602 | quatre cocos
# Processing City # 365 of 602 | hirara
# Processing City # 366 of 602 | chernaya kholunitsa
# Processing City # 367 of 602 | comodoro rivadavia
# Processing City # 368 of 602 | zwedru
# Processing City # 369 of 602 | tura
# Processing City # 370 of 602 | raga
# city not found. skipping....
# Processing City # 371 of 602 | veere
# Processing City # 372 of 602 | flin flon
# Processing City # 373 of 602 | biloela
# Processing City # 374 of 602 | tarudant
# city not found. skipping....
# Processing City # 375 of 602 | klaksvik
# Processing City # 376 of 602 | moses lake
# Processing City # 377 of 602 | nokaneng
# Processing City # 378 of 602 | kudahuvadhoo
# Processing City # 379 of 602 | celestun
# Processing City # 380 of 602 | san jeronimo
# Processing City # 381 of 602 | zhezkazgan
# Processing City # 382 of 602 | okahandja
# Processing City # 383 of 602 | mukdahan
# Processing City # 384 of 602 | vawkavysk
# Processing City # 385 of 602 | opobo
# city not found. skipping....
# Processing City # 386 of 602 | ust-nera
# Processing City # 387 of 602 | charters towers
# Processing City # 388 of 602 | catuday
# Processing City # 389 of 602 | chicama
# Processing City # 390 of 602 | luganville
# Processing City # 391 of 602 | yumen
# Processing City # 392 of 602 | dalupaon
# Processing City # 393 of 602 | parabel
# Processing City # 394 of 602 | adeje
# Processing City # 395 of 602 | makokou
# Processing City # 396 of 602 | yabrud
# Processing City # 397 of 602 | kalamare
# Processing City # 398 of 602 | cayenne
# Processing City # 399 of 602 | bandarbeyla
# Processing City # 400 of 602 | goderich
# Processing City # 401 of 602 | talnakh
# Processing City # 402 of 602 | corinto
# Processing City # 403 of 602 | nemuro
# Processing City # 404 of 602 | onega
# Processing City # 405 of 602 | bonavista
# Processing City # 406 of 602 | neryungri
# Processing City # 407 of 602 | vizinga
# Processing City # 408 of 602 | neyshabur
# Processing City # 409 of 602 | bull savanna
# Processing City # 410 of 602 | atambua
# Processing City # 411 of 602 | sao miguel
# Processing City # 412 of 602 | satitoa
# city not found. skipping....
# Processing City # 413 of 602 | vila
# Processing City # 414 of 602 | karkaralinsk
# city not found. skipping....
# Processing City # 415 of 602 | rio grande
# Processing City # 416 of 602 | sobradinho
# Processing City # 417 of 602 | chai badan
# Processing City # 418 of 602 | sobolevo
# Processing City # 419 of 602 | lata
# Processing City # 420 of 602 | balaguer
# Processing City # 421 of 602 | san felipe
# Processing City # 422 of 602 | sitka
# Processing City # 423 of 602 | marovoay
# Processing City # 424 of 602 | kvarkeno
# Processing City # 425 of 602 | nizhniy kuranakh
# Processing City # 426 of 602 | senno
# Processing City # 427 of 602 | xinpu
# Processing City # 428 of 602 | brownwood
# Processing City # 429 of 602 | burica
# city not found. skipping....
# Processing City # 430 of 602 | bolungarvik
# city not found. skipping....
# Processing City # 431 of 602 | chake chake
# Processing City # 432 of 602 | channel-port aux basques
# Processing City # 433 of 602 | atikokan
# Processing City # 434 of 602 | el wasta
# city not found. skipping....
# Processing City # 435 of 602 | aitape
# Processing City # 436 of 602 | coihaique
# Processing City # 437 of 602 | gamba
# Processing City # 438 of 602 | namatanai
# Processing City # 439 of 602 | ketchikan
# Processing City # 440 of 602 | akureyri
# Processing City # 441 of 602 | santa maria
# Processing City # 442 of 602 | hamilton
# Processing City # 443 of 602 | ternova
# Processing City # 444 of 602 | vesyegonsk
# Processing City # 445 of 602 | santa marta
# Processing City # 446 of 602 | codrington
# Processing City # 447 of 602 | chibuto
# Processing City # 448 of 602 | katsuura
# Processing City # 449 of 602 | lillooet
# Processing City # 450 of 602 | ewo
# Processing City # 451 of 602 | port lincoln
# Processing City # 452 of 602 | kavaratti
# Processing City # 453 of 602 | sungaipenuh
# Processing City # 454 of 602 | marsh harbour
# Processing City # 455 of 602 | skjervoy
# Processing City # 456 of 602 | buchanan
# Processing City # 457 of 602 | zambezi
# Processing City # 458 of 602 | dzhida
# Processing City # 459 of 602 | auki
# Processing City # 460 of 602 | sechura
# Processing City # 461 of 602 | lobva
# Processing City # 462 of 602 | vostok
# Processing City # 463 of 602 | lamu
# Processing City # 464 of 602 | yenotayevka
# Processing City # 465 of 602 | bathsheba
# Processing City # 466 of 602 | trat
# Processing City # 467 of 602 | pocoes
# Processing City # 468 of 602 | adelaide
# Processing City # 469 of 602 | gornopravdinsk
# Processing City # 470 of 602 | pisco
# Processing City # 471 of 602 | puerto madero
# Processing City # 472 of 602 | port keats
# Processing City # 473 of 602 | tamiahua
# Processing City # 474 of 602 | rapid valley
# Processing City # 475 of 602 | san carlos de bariloche
# Processing City # 476 of 602 | vyazemskiy
# Processing City # 477 of 602 | muzaffargarh
# Processing City # 478 of 602 | mansa
# Processing City # 479 of 602 | dongobesh
# Processing City # 480 of 602 | nouadhibou
# Processing City # 481 of 602 | yatou
# Processing City # 482 of 602 | pilar
# Processing City # 483 of 602 | roald
# Processing City # 484 of 602 | puri
# Processing City # 485 of 602 | sao joao da barra
# Processing City # 486 of 602 | plouzane
# Processing City # 487 of 602 | gilbues
# Processing City # 488 of 602 | ponca city
# Processing City # 489 of 602 | turinsk
# Processing City # 490 of 602 | vigia
# Processing City # 491 of 602 | ndende
# city not found. skipping....
# Processing City # 492 of 602 | llangefni
# Processing City # 493 of 602 | berdigestyakh
# Processing City # 494 of 602 | carlsbad
# Processing City # 495 of 602 | elk river
# Processing City # 496 of 602 | fort nelson
# Processing City # 497 of 602 | alice springs
# Processing City # 498 of 602 | auburn
# Processing City # 499 of 602 | brodokalmak
# Processing City # 500 of 602 | palabuhanratu
# city not found. skipping....
# Processing City # 501 of 602 | mitzic
# Processing City # 502 of 602 | ancud
# Processing City # 503 of 602 | vestmanna
# Processing City # 504 of 602 | biryusinsk
# Processing City # 505 of 602 | juan lacaze
# Processing City # 506 of 602 | tromso
# Processing City # 507 of 602 | paamiut
# Processing City # 508 of 602 | iracoubo
# Processing City # 509 of 602 | yankton
# Processing City # 510 of 602 | sarahan
# Processing City # 511 of 602 | severo-yeniseyskiy
# Processing City # 512 of 602 | high prairie
# Processing City # 513 of 602 | soe
# Processing City # 514 of 602 | daru
# Processing City # 515 of 602 | inta
# Processing City # 516 of 602 | pacifica
# Processing City # 517 of 602 | melilla
# Processing City # 518 of 602 | northam
# Processing City # 519 of 602 | itoman
# Processing City # 520 of 602 | touros
# Processing City # 521 of 602 | bilma
# Processing City # 522 of 602 | tuscaloosa
# Processing City # 523 of 602 | prosvet
# Processing City # 524 of 602 | morondava
# Processing City # 525 of 602 | talcahuano
# Processing City # 526 of 602 | filingue
# Processing City # 527 of 602 | kegayli
# city not found. skipping....
# Processing City # 528 of 602 | tapaua
# city not found. skipping....
# Processing City # 529 of 602 | bernalillo
# Processing City # 530 of 602 | zvishavane
# Processing City # 531 of 602 | xai-xai
# Processing City # 532 of 602 | matara
# Processing City # 533 of 602 | bowen
# Processing City # 534 of 602 | iralaya
# Processing City # 535 of 602 | kununurra
# Processing City # 536 of 602 | mananjary
# Processing City # 537 of 602 | camacha
# Processing City # 538 of 602 | barra patuca
# Processing City # 539 of 602 | vila velha
# Processing City # 540 of 602 | sabang
# Processing City # 541 of 602 | la union
# Processing City # 542 of 602 | vao
# Processing City # 543 of 602 | ambilobe
# Processing City # 544 of 602 | srednekolymsk
# Processing City # 545 of 602 | padang
# Processing City # 546 of 602 | tsiroanomandidy
# Processing City # 547 of 602 | fairbanks
# Processing City # 548 of 602 | sao gabriel da cachoeira
# Processing City # 549 of 602 | troutdale
# Processing City # 550 of 602 | jawhar
# Processing City # 551 of 602 | baykit
# Processing City # 552 of 602 | saint-joseph
# Processing City # 553 of 602 | maneromango
# Processing City # 554 of 602 | zarand
# Processing City # 555 of 602 | bukama
# Processing City # 556 of 602 | roma
# Processing City # 557 of 602 | cockburn town
# Processing City # 558 of 602 | yichang
# Processing City # 559 of 602 | sokolovyy
# Processing City # 560 of 602 | petropavlovsk-kamchatskiy
# Processing City # 561 of 602 | havelock
# Processing City # 562 of 602 | isabela
# Processing City # 563 of 602 | asyut
# Processing City # 564 of 602 | bolitoc
# Processing City # 565 of 602 | cappelle-la-grande
# Processing City # 566 of 602 | areosa
# Processing City # 567 of 602 | villarrica
# Processing City # 568 of 602 | nishihara
# Processing City # 569 of 602 | srivardhan
# Processing City # 570 of 602 | mariara
# Processing City # 571 of 602 | rio gallegos
# Processing City # 572 of 602 | alofi
# Processing City # 573 of 602 | kodinar
# Processing City # 574 of 602 | pousat
# city not found. skipping....
# Processing City # 575 of 602 | kaeo
# Processing City # 576 of 602 | mendahara
# city not found. skipping....
# Processing City # 577 of 602 | ulaanbaatar
# Processing City # 578 of 602 | geresk
# city not found. skipping....
# Processing City # 579 of 602 | abu kamal
# Processing City # 580 of 602 | havre-saint-pierre
# Processing City # 581 of 602 | ahvaz
# Processing City # 582 of 602 | sorvag
# city not found. skipping....
# Processing City # 583 of 602 | santa eulalia del rio
# city not found. skipping....
# Processing City # 584 of 602 | deloraine
# Processing City # 585 of 602 | egvekinot
# Processing City # 586 of 602 | bundaberg
# Processing City # 587 of 602 | tambo
# Processing City # 588 of 602 | labuhan
# Processing City # 589 of 602 | santa lucia
# Processing City # 590 of 602 | iquique
# Processing City # 591 of 602 | iisalmi
# Processing City # 592 of 602 | chaman
# Processing City # 593 of 602 | gisborne
# Processing City # 594 of 602 | peniche
# Processing City # 595 of 602 | goryachegorsk
# Processing City # 596 of 602 | sadovoye
# Processing City # 597 of 602 | sinkat
# city not found. skipping....
# Processing City # 598 of 602 | the pas
# Processing City # 599 of 602 | oskaloosa
# Processing City # 600 of 602 | laguna
# Processing City # 601 of 602 | sao jose do calcado

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#combine all of the lists
df = {'City': city_list, 'Cloudiness':cloudiness , 'Country':country, 'Date':date, 'Humidity':humidity, 'Lat':lat, 'Lng':lng, 
      'Max Temp':maxtemp, 'Wind Speed':windspeed}

# %%
#create a dataframe
df = pd.DataFrame(data = df)

# %%
#double check the tranformation
df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0     aklavik          75      CA  1552827600        63  68.22  68.22
# 1       kapit          36      MY  1552829845        94   2.02   2.02
# 2    hermanus          36      ZA  1552829488        79 -34.42 -34.42
# 3     vilhena           0      BR  1552827600        83 -12.74 -12.74
# 4  georgetown          75      GY  1552827600        74   6.80   6.80
#
#    Max Temp  Wind Speed
# 0     28.40       17.22
# 1     70.75        1.95
# 2     73.99        5.01
# 3     77.00        6.93
# 4     84.20       16.11

# %%
#check total data points, 546
df.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
#export to excel
df.to_csv("Weather_Data.csv", encoding="utf-8",header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df['Lat'], df['Max Temp'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Max Temp ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (f)')
plt.grid()
plt.savefig('Latitude_vs_MaxTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df['Lat'], df['Humidity'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Humidity ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Humidity (%)')
plt.ylim(top=105) #ylim set to 100 as there was one mistake in a city entry with 300% humidity
plt.grid()
plt.savefig('Latitude_vs_Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Lat'], df['Cloudiness'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%m/%d/%y')})")
plt.xlabel('City Latitude') 
plt.ylabel('Cloudiness(%)')
plt.grid()
plt.savefig('Latitude_vs_Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Lat'], df['Wind Speed'], marker="o", facecolors="steelblue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%m/%d/%y')})")
plt.xlabel('City Latitude') 
plt.ylabel('Wind Speed(mph)')
plt.grid()
plt.savefig('Latitude_vs_Wind Speed.png')
